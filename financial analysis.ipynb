# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %%
df = pd.read_excel("C:/Users/Falguni Jain/Downloads/financial_data.xlsx")
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
print(df)
# Out:
#             Revenue  Expenses
# Date
# 2018-01-31    52483     28083
# 2018-02-28    50495     30104
# 2018-03-31    55611     27269
# 2018-04-30    61174     27757
# 2018-05-31    53574     36639
# 2018-06-30    54761     39662
# 2018-07-31    65014     34796
# 2018-08-31    62142     39946
# 2018-09-30    57144     38226
# 2018-10-31    63390     35046
# 2018-11-30    59547     39920
# 2018-12-31    60722     45474
# 2019-01-31    65447     40026
# 2019-02-28    55857     47275
# 2019-03-31    57985     31385
# 2019-04-30    64985     45999
# 2019-05-31    63918     43907
# 2019-06-30    71740     43210
# 2019-07-31    66815     45621
# 2019-08-31    65480     38151
# 2019-09-30    81057     46070
# 2019-10-31    73786     49225
# 2019-11-30    76439     54555
# 2019-12-31    70164     47418
# 2020-01-31    75752     47105
# 2020-02-29    80215     49179
# 2020-03-31    75092     55695
# 2020-04-30    83912     54196
# 2020-05-31    80217     51609
# 2020-06-30    82948     56629
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of             Revenue  Expenses
# Date
# 2018-01-31    52483     28083
# 2018-02-28    50495     30104
# 2018-03-31    55611     27269
# 2018-04-30    61174     27757
# 2018-05-31    53574     36639
# 2018-06-30    54761     39662
# 2018-07-31    65014     34796
# 2018-08-31    62142     39946
# 2018-09-30    57144     38226
# 2018-10-31    63390     35046
# 2018-11-30    59547     39920
# 2018-12-31    60722     45474
# 2019-01-31    65447     40026
# 2019-02-28    55857     47275
# 2019-03-31    57985     31385
# 2019-04-30    64985     45999
# 2019-05-31    63918     43907
# 2019-06-30    71740     43210
# 2019-07-31    66815     45621
# 2019-08-31    65480     38151
# 2019-09-30    81057     46070
# 2019-10-31    73786     49225
# 2019-11-30    76439     54555
# 2019-12-31    70164     47418
# 2020-01-31    75752     47105
# 2020-02-29    80215     49179
# 2020-03-31    75092     55695
# 2020-04-30    83912     54196
# 2020-05-31    80217     51609
# ...

# %%
df.head()
# Out:
#             Revenue  Expenses
# Date
# 2018-01-31    52483     28083
# 2018-02-28    50495     30104
# 2018-03-31    55611     27269
# 2018-04-30    61174     27757
# 2018-05-31    53574     36639

# %%
df.tail()
# Out:
#             Revenue  Expenses
# Date
# 2022-08-31   119910     77816
# 2022-09-30   112244     77318
# 2022-10-31   116081     73630
# 2022-11-30   120469     83723
# 2022-12-31   124877     83007

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Revenue  Expenses
# Date
# 2018-01-31    52483     28083
# 2018-02-28    50495     30104
# 2018-03-31    55611     27269
# 2018-04-30    61174     27757
# 2018-05-31    53574     36639
# 2018-06-30    54761     39662
# 2018-07-31    65014     34796
# 2018-08-31    62142     39946
# 2018-09-30    57144     38226
# 2018-10-31    63390     35046
# 2018-11-30    59547     39920
# 2018-12-31    60722     45474
# 2019-01-31    65447     40026
# 2019-02-28    55857     47275
# 2019-03-31    57985     31385
# 2019-04-30    64985     45999
# 2019-05-31    63918     43907
# 2019-06-30    71740     43210
# 2019-07-31    66815     45621
# 2019-08-31    65480     38151
# 2019-09-30    81057     46070
# 2019-10-31    73786     49225
# 2019-11-30    76439     54555
# 2019-12-31    70164     47418
# 2020-01-31    75752     47105
# 2020-02-29    80215     49179
# 2020-03-31    75092     55695
# 2020-04-30    83912     54196
# ...

# %%
df.describe()
# Out:
#              Revenue      Expenses
# count      60.000000     60.000000
# mean    84226.233333  54984.766667
# std     21151.367031  15416.604438
# min     50495.000000  27269.000000
# 25%     65006.750000  43732.750000
# 50%     83405.500000  55125.000000
# 75%     99580.750000  65183.250000
# max    124877.000000  84768.000000

# %%
df.shape
# Out:
# (60, 2)

# %%
df.isnull()
# Out:
#             Revenue  Expenses
# Date
# 2018-01-31    False     False
# 2018-02-28    False     False
# 2018-03-31    False     False
# 2018-04-30    False     False
# 2018-05-31    False     False
# 2018-06-30    False     False
# 2018-07-31    False     False
# 2018-08-31    False     False
# 2018-09-30    False     False
# 2018-10-31    False     False
# 2018-11-30    False     False
# 2018-12-31    False     False
# 2019-01-31    False     False
# 2019-02-28    False     False
# 2019-03-31    False     False
# 2019-04-30    False     False
# 2019-05-31    False     False
# 2019-06-30    False     False
# 2019-07-31    False     False
# 2019-08-31    False     False
# 2019-09-30    False     False
# 2019-10-31    False     False
# 2019-11-30    False     False
# 2019-12-31    False     False
# 2020-01-31    False     False
# 2020-02-29    False     False
# 2020-03-31    False     False
# 2020-04-30    False     False
# 2020-05-31    False     False
# 2020-06-30    False     False
# ...

# %%
df.isnull().sum()
# Out:
# Revenue     0
# Expenses    0
# dtype: int64

# %%
def forecast_series(series, steps=12):
    model = ARIMA(series, order=(1,1,1))  # ARIMA(p,d,q)
    model_fit = model.fit()
    forecast = model_fit.forecast(steps=steps)
    return forecast

# %%
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
else:
    print("Date is already the index")
# Out:
# Date is already the index

# %%
print(df.head())
print(df.columns)
# Out:
#             Revenue  Expenses
# Date
# 2018-01-31    52483     28083
# 2018-02-28    50495     30104
# 2018-03-31    55611     27269
# 2018-04-30    61174     27757
# 2018-05-31    53574     36639
# Index(['Revenue', 'Expenses'], dtype='object')

# %%
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

print("Data Preview:")
print(df.head())
# Out:
# Data Preview:
#             Revenue  Expenses
# Date
# 2018-01-31    52483     28083
# 2018-02-28    50495     30104
# 2018-03-31    55611     27269
# 2018-04-30    61174     27757
# 2018-05-31    53574     36639

# %%
def forecast_series(series, steps=12):
    model = ARIMA(series, order=(1,1,1))  # ARIMA(p,d,q)
    model_fit = model.fit()
    forecast = model_fit.forecast(steps=steps)

# %%
future_dates = pd.date_range(df.index[-1] + pd.DateOffset(months=1), periods=12, freq='ME')
forecast_df = pd.DataFrame({
    "Date": future_dates,
    "Revenue_Forecast": revenue_forecast,
    "Expenses_Forecast": expenses_forecast
})

print("\nForecasted Data:")
print(forecast_df)
# Out:
# Forecasted Data:
#                  Date  Revenue_Forecast  Expenses_Forecast
# 2023-01-31 2023-01-31     123760.373414       82241.613703
# 2023-02-28 2023-02-28     123862.129192       82284.041075
# 2023-03-31 2023-03-31     123852.856406       82281.689215
# 2023-04-30 2023-04-30     123853.701415       82281.819585
# 2023-05-31 2023-05-31     123853.624412       82281.812358
# 2023-06-30 2023-06-30     123853.631429       82281.812758
# 2023-07-31 2023-07-31     123853.630789       82281.812736
# 2023-08-31 2023-08-31     123853.630848       82281.812737
# 2023-09-30 2023-09-30     123853.630842       82281.812737
# 2023-10-31 2023-10-31     123853.630843       82281.812737
# 2023-11-30 2023-11-30     123853.630843       82281.812737
# 2023-12-31 2023-12-31     123853.630843       82281.812737

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index, df['Revenue'], label="Historical Revenue")
plt.plot(df.index, df['Expenses'], label="Historical Expenses")
plt.plot(future_dates, revenue_forecast, label="Forecast Revenue", linestyle="--")
plt.plot(future_dates, expenses_forecast, label="Forecast Expenses", linestyle="--")
plt.legend()
plt.title("Financial Forecasting: Revenue & Expenses")
plt.xlabel("Date")
plt.ylabel("Amount")
plt.grid(True)
plt.show()
